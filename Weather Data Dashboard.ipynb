# %%
import pandas as pd
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
import os
import pandas as pd

notebook_dir = os.getcwd()
data_dir = os.path.join(notebook_dir, "data")
os.makedirs(data_dir, exist_ok=True)

csv_path = os.path.join(data_dir, "weather_sample.csv")

# Always create CSV (overwrite if exists)
sample_data = {
    "date": ["2025-01-01","2025-01-02","2025-01-03","2025-01-04","2025-01-05",
             "2025-01-06","2025-01-07","2025-01-08","2025-01-09","2025-01-10"],
    "temperature": [22,24,19,18,25,27,21,20,23,26],
    "humidity": [60,65,70,72,55,50,68,75,63,58],
    "wind_speed": [5,7,10,12,6,4,8,9,5,4],
    "rainfall": [0,0,2,5,0,0,1,3,0,0],
    "cloud_cover": [20,30,80,90,25,10,60,85,40,30]
}

df = pd.DataFrame(sample_data)
df.to_csv(csv_path, index=False)
print(f"CSV created/overwritten at {csv_path}")

# Preview data
df.head()
# Out:
# CSV created/overwritten at C:\Users\zandi\data\weather_sample.csv
#          date  temperature  humidity  wind_speed  rainfall  cloud_cover
# 0  2025-01-01           22        60           5         0           20
# 1  2025-01-02           24        65           7         0           30
# 2  2025-01-03           19        70          10         2           80
# 3  2025-01-04           18        72          12         5           90
# 4  2025-01-05           25        55           6         0           25

# %%
# Converted 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

# Preview updated DataFrame
df.head()
# Out:
#         date  temperature  humidity  wind_speed  rainfall  cloud_cover
# 0 2025-01-01           22        60           5         0           20
# 1 2025-01-02           24        65           7         0           30
# 2 2025-01-03           19        70          10         2           80
# 3 2025-01-04           18        72          12         5           90
# 4 2025-01-05           25        55           6         0           25

# %%
# Basic info
print("Dataset shape:", df.shape)
print("\nDataset info:")
print(df.info())

# Summary statistics
df.describe()
# Out:
# Dataset shape: (10, 6)
#
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         10 non-null     datetime64[ns]
#  1   temperature  10 non-null     int64
#  2   humidity     10 non-null     int64
#  3   wind_speed   10 non-null     int64
#  4   rainfall     10 non-null     int64
#  5   cloud_cover  10 non-null     int64
# dtypes: datetime64[ns](1), int64(5)
# memory usage: 612.0 bytes
# None
#                       date  temperature   humidity  wind_speed  rainfall  \
# count                   10     10.00000  10.000000   10.000000  10.00000
# mean   2025-01-05 12:00:00     22.50000  63.600000    7.000000   1.10000
# min    2025-01-01 00:00:00     18.00000  50.000000    4.000000   0.00000
# 25%    2025-01-03 06:00:00     20.25000  58.500000    5.000000   0.00000
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(df['date'], df['temperature'], marker='o', linestyle='-', color='tomato')
plt.title("Temperature Over Time (2025)")  # removed emoji
plt.xlabel("Date")
plt.ylabel("Temperature (°C)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['date'], df['humidity'], marker='s', linestyle='--', color='skyblue')
plt.title("Humidity Over Time (2025)")
plt.xlabel("Date")
plt.ylabel("Humidity (%)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(df['date'], df['wind_speed'], marker='^', label="Wind Speed", color='green')
plt.plot(df['date'], df['rainfall'], marker='v', label="Rainfall", color='blue')
plt.title("Wind Speed & Rainfall Over Time (2025)")
plt.xlabel("Date")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.show()

# %%
avg_temp = df['temperature'].mean()
avg_humidity = df['humidity'].mean()
avg_wind = df['wind_speed'].mean()
avg_rain = df['rainfall'].mean()
avg_cloud = df['cloud_cover'].mean()

print(f"Average Temperature: {avg_temp:.2f} °C")
print(f"Average Humidity: {avg_humidity:.2f} %")
print(f"Average Wind Speed: {avg_wind:.2f} km/h")
print(f"Average Rainfall: {avg_rain:.2f} mm")
print(f"Average Cloud Cover: {avg_cloud:.2f} %")
# Out:
# Average Temperature: 22.50 °C
# Average Humidity: 63.60 %
# Average Wind Speed: 7.00 km/h
# Average Rainfall: 1.10 mm
# Average Cloud Cover: 47.00 %
